# %% [markdown]
# <a href="https://colab.research.google.com/github/YisusBe/ProyectodePrueba/blob/main/Copia_de_Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = input("Ingrese su nombre: ")
apellido = input("Ingrese su apellido: ")
#fecha
import datetime
#valores
pisos = 10
departamentos_por_piso = 4
departamentos_disponibles = [[True] * departamentos_por_piso for _ in range(pisos)]
compradores = []
precios = {
    'A': 3800,
    'B': 3000,
    'C': 2800,
    'D': 3500
}

#definiciones

def Elmenu():
    print("----------------")
    print("======MENÚ======")
    print("----------------")
    print("1- Comprar un departamento: ")
    print("2- Ver los departamentos disponibles: ")
    print("3- Ver el listado de compradores: ")
    print("4- Ver las ganancias totales: ")
    print("5- Salir: ")
    opcion = input("Seleccione una opción: ")
    return opcion

def comprar_depa():
    print("Departamentos disponibles:")
    ver_departamentos()
    piso = int(input("Ingrese el número de piso: "))
    tipo = input("Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : ")
    departamento = tipo + str(piso)

    if not departamento_valido(departamento):
        print("Departamento inválido. Por favor, seleccione otro.")
        return

    if not departamento_disponible(departamento):
        print("El departamento seleccionado no está disponible. Por favor, seleccione otro.")
        return

    run = input("Ingrese el RUN del comprador (sin guion ni puntos): ")
    comprar_departamento_aux(departamento, run)
    print("La operación fue realizada correctamente.")

def comprar_departamento_aux(departamento, run):
    index = obtener_indice_departamento(departamento)
    departamentos_disponibles[index[0]][index[1]] = False
    compradores.append((departamento, run))

def ver_departamentos():
    for piso in range(1, pisos + 1):
        print(f"Piso {piso}: ", end="")
        for departamento in range(departamentos_por_piso):
            if departamentos_disponibles[piso - 1][departamento]:
                print(f"{chr(65 + departamento)}{piso}", end=" ")
            else:
                print("X", end=" ")
        print()

def ver_listado_compradores():
    compradores_ordenados = sorted(compradores, key=lambda x: int(x[1]))
    print("Listado de compradores:")
    for compra in compradores_ordenados:
        print(f"{compra[0]}: {compra[1]}")

def ver_ganancias_totales():
    total_por_tipo = {}
    for compra in compradores:
        tipo = compra[0][0]
        if tipo in total_por_tipo:
            total_por_tipo[tipo] += precios[tipo]
        else:
            total_por_tipo[tipo] = precios[tipo]

    total_general = sum(total_por_tipo.values())

    print("=====Ventas totales=====:")
    print("Tipo de Departamento\tCantidad\tTotal")
    for tipo, total in total_por_tipo.items():
        cantidad = total // precios[tipo]
        print(f"Tipo {tipo} {precios[tipo]} UF_____________{cantidad}____________{total} UF")

    print(f"TOTAL---> {len(compradores)} = {total_general} UF")

def departamento_valido(departamento):
    return departamento[0] in ['A', 'B', 'C', 'D'] and int(departamento[1:]) >= 1 and int(departamento[1:]) <= pisos

def departamento_disponible(departamento):
    index = obtener_indice_departamento(departamento)
    return departamentos_disponibles[index[0]][index[1]]

def obtener_indice_departamento(departamento):
    piso = int(departamento[1:]) - 1
    tipo = ord(departamento[0]) - 65
    return piso, tipo

def mostrar_salida():
    fecha_actual = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    print(f"Muchas gracias por usar el sistema, {nombre} {apellido}.\nFecha de salida: {fecha_actual}")

def main():
    while True:
        opcion = Elmenu()

        if opcion == "1":
            comprar_depa()
        elif opcion == "2":
            ver_departamentos()
        elif opcion == "3":
            ver_listado_compradores()
        elif opcion == "4":
            ver_ganancias_totales()
        elif opcion == "5":
            mostrar_salida()
            break
        else:
            print("La opción es inválida. Por favor, seleccione de nuevo una opcion valida.")

if __name__ == "__main__":
    main()
# Out:
# Ingrese su nombre: Leonel
# Ingrese su apellido: Benites
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 1
# Departamentos disponibles:
# Piso 1: A1 B1 C1 D1
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: A5 B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# Ingrese el número de piso: 1
# Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : A
# Ingrese el RUN del comprador (sin guion ni puntos): 217333822
# La operación fue realizada correctamente.
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 1
# Departamentos disponibles:
# Piso 1: X B1 C1 D1
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: A5 B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# Ingrese el número de piso: 5
# Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : A
# Ingrese el RUN del comprador (sin guion ni puntos): 1312312
# La operación fue realizada correctamente.
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 1
# Departamentos disponibles:
# Piso 1: X B1 C1 D1
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: X B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# Ingrese el número de piso: 1
# Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : B
# Ingrese el RUN del comprador (sin guion ni puntos): 1212211
# La operación fue realizada correctamente.
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 1
# Departamentos disponibles:
# Piso 1: X X C1 D1
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: X B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# Ingrese el número de piso: 1
# Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : C
# Ingrese el RUN del comprador (sin guion ni puntos): 423424
# La operación fue realizada correctamente.
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 1
# Departamentos disponibles:
# Piso 1: X X X D1
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: X B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# Ingrese el número de piso: 1
# Ingrese el tipo de departamento considerando las opciones como: A, B, C, D : D
# Ingrese el RUN del comprador (sin guion ni puntos): 4313123
# La operación fue realizada correctamente.
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 2
# Piso 1: X X X X
# Piso 2: A2 B2 C2 D2
# Piso 3: A3 B3 C3 D3
# Piso 4: A4 B4 C4 D4
# Piso 5: X B5 C5 D5
# Piso 6: A6 B6 C6 D6
# Piso 7: A7 B7 C7 D7
# Piso 8: A8 B8 C8 D8
# Piso 9: A9 B9 C9 D9
# Piso 10: A10 B10 C10 D10
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 3
# Listado de compradores:
# C1: 423424
# B1: 1212211
# A5: 1312312
# D1: 4313123
# A1: 217333822
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 4
# =====Ventas totales=====:
# Tipo de Departamento	Cantidad	Total
# Tipo A 3800 UF_____________2____________7600 UF
# Tipo B 3000 UF_____________1____________3000 UF
# Tipo C 2800 UF_____________1____________2800 UF
# Tipo D 3500 UF_____________1____________3500 UF
# TOTAL---> 5 = 16900 UF
# ----------------
# ======MENÚ======
# ----------------
# 1- Comprar un departamento:
# 2- Ver los departamentos disponibles:
# 3- Ver el listado de compradores:
# 4- Ver las ganancias totales:
# 5- Salir:
# Seleccione una opción: 5
# Muchas gracias por usar el sistema, Leonel Benites.
# Fecha de salida: 11/07/2023 01:22:50
